# %%
# Title

Example de traitement de donnée d'un data set

# %%
# %pip install -q seaborn

# %%
import xlrd
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
titanic = pd.read_excel('./titanic.xls')

titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
titanic.shape
# Out:
# (1309, 14)

# %%
titanic.dtypes
# Out:
# pclass         int64
# survived       int64
# name          object
# sex           object
# age          float64
# sibsp          int64
# parch          int64
# ticket        object
# fare         float64
# cabin         object
# embarked      object
# boat          object
# body         float64
# home.dest     object
# dtype: object

# %%
df = titanic.copy()

# %%
sns.heatmap(df.isna())
# Out:
# <Axes: >

# %%
df['survived'].value_counts()
# Out:
# survived
# 0    809
# 1    500
# Name: count, dtype: int64

# %%
df['survived'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(6,6))
plt.pie(df['survived'].value_counts(), labels=['died', 'survived'], autopct='%1.f%%')
plt.title('Title de mon graphique')
plt.show()

# %%
df_survived = df[df['survived'] == 1]
df_died = df[df['survived'] == 0]

df['pclass'].value_counts()
# Out:
# pclass
# 3    709
# 1    323
# 2    277
# Name: count, dtype: int64

# %%
df_class1 = df[df['pclass'] == 1]
df_class2 = df[df['pclass'] == 2]
df_class3 = df[df['pclass'] == 3]

# %%
df_class1['survived'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
df_class2['survived'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
df_class3['survived'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
# Je récupère les personnes qui ont plus de 30 ans
df[(df['age'] > 30)]
# Out:
#       pclass  survived                                             name  \
# 5          1         1                              Anderson, Mr. Harry
# 6          1         1                Andrews, Miss. Kornelia Theodosia
# 7          1         0                           Andrews, Mr. Thomas Jr
# 8          1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9          1         0                          Artagaveytia, Mr. Ramon
# ...      ...       ...                                              ...
# 1286       3         1  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1287       3         0                 Widegren, Mr. Carl/Charles Peter
# 1290       3         1                 Wilkes, Mrs. James (Ellen Needs)
# 1298       3         0                        Wittevrongel, Mr. Camille
# 1301       3         0                             Youseff, Mr. Gerious
#
#          sex   age  sibsp  parch    ticket     fare cabin embarked boat  \
# ...

# %%
# Je récupère les personnes qui ont plus de 30 ans
df[(df['age'] > 30) & (df['survived'] == 1)]
# Out:
#       pclass  survived                                             name  \
# 5          1         1                              Anderson, Mr. Harry
# 6          1         1                Andrews, Miss. Kornelia Theodosia
# 8          1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 14         1         1             Barkworth, Mr. Algernon Henry Wilson
# 17         1         1  Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# ...      ...       ...                                              ...
# 1228       3         1                               Stranden, Mr. Juho
# 1233       3         1                        Sundman, Mr. Johan Julian
# 1261       3         1                           Turkula, Mrs. (Hedwig)
# 1286       3         1  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1290       3         1                 Wilkes, Mrs. James (Ellen Needs)
#
#          sex   age  sibsp  parch             ticket      fare    cabin  \
# ...

# %%
def age_cat(data):
    if(data['age'] < 18):
        return '-18'
    elif(data['age'] < 30):
        return '20s'
    elif(data['age'] < 60):
        return '30-60'
    else:
        return '60+'

df['age_cat'] = df.apply(age_cat, axis=1)
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest age_cat
# ...

# %%
df.select_dtypes('float')
# Out:
#           age      fare   body
# 0     29.0000  211.3375    NaN
# 1      0.9167  151.5500    NaN
# 2      2.0000  151.5500    NaN
# 3     30.0000  151.5500  135.0
# 4     25.0000  151.5500    NaN
# ...       ...       ...    ...
# 1304  14.5000   14.4542  328.0
# 1305      NaN   14.4542    NaN
# 1306  26.5000    7.2250  304.0
# 1307  27.0000    7.2250    NaN
# 1308  29.0000    7.8750    NaN
#
# [1309 rows x 3 columns]

# %%
df = df.drop(columns=['body', 'fare'])

for col in df.select_dtypes('float'):
    plt.figure(figsize=(20,10))
    sns.displot(df_survived[col], label='survived')
    sns.displot(df_died[col], label='died')
    plt.legend()

# %%
for col in df.select_dtypes('float'):
    plt.figure(figsize=(20,10))
    sns.displot(data=df, x=col, hue='survived')
    plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
